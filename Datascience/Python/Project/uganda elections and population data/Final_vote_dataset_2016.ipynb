# %% [markdown]
# #                          Uganda Presidential Elections 2016

# %%
import pandas as pd
import numpy as np
#load Csv
df=pd.read_csv("final-vote-by-district-2016-presidential.csv")

# %%
df
# Out:
#             DISTRICT  REG.VOTERS   PDP     GF   PPP    FP    FDC  INDEP  \
# 0          001 APAC       152061  1282   1267  1307   373  38644    444
# 1          002 ARUA       336384  3737   5215  3341  1313  68108   1121
# 2    003 BUNDIBUGYO        98976   300    457   158   123   8923     69
# 3      004 BUSHENYI       124934   270    490   268   182  26654    155
# 4          005 GULU       184791  1719  10487  1794   835  48594    478
# ..               ...         ...   ...    ...   ...   ...    ...    ...
# 107        108 NGORA       62952   529    652   513   167  21337    160
# 108      109 BUHWEJU       57847   252    398   272   121   5421     76
# 109        110 NWOYA       46836   667   4984   573   186   6838    275
# 110        111 AGAGO       85759   859   2217   663   330  19204    224
# 111     112 RUBIRIZI       63006   163    367   316    69   9974     50
#
#         NRM  VALD VOTES  INVALID  TOTAL VOTES LEADER
# ...

# %%
#look for null values from the data set
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DISTRICT     112 non-null    object
#  1   REG.VOTERS   112 non-null    int64
#  2   PDP          112 non-null    int64
#  3   GF           112 non-null    int64
#  4   PPP          112 non-null    int64
#  5   FP           112 non-null    int64
#  6   FDC          112 non-null    int64
#  7   INDEP        112 non-null    int64
#  8   NRM          112 non-null    int64
#  9   VALD VOTES   112 non-null    int64
#  10  INVALID      112 non-null    int64
#  11  TOTAL VOTES  112 non-null    int64
#  12  LEADER       112 non-null    object
# dtypes: int64(11), object(2)
# memory usage: 11.5+ KB

# %%
#count how many district are in te dataset
#get only unique districts with no duplicates
district_distict=df.DISTRICT.unique()
#convert data to pandas dataframe
district_df=pd.DataFrame(district_distict,columns=['distinct_districts'])
#count distinct districts
district_count=district_df.count()
district_count
# Out:
# distinct_districts    112
# dtype: int64
